# %% [markdown]
# <a href="https://colab.research.google.com/github/komo135/tradingrl/blob/master/neuro_evolution_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Google ドライブをマウントするには、このセルを実行してください。
from google.colab import drive
drive.mount('/content/drive')

# %cd drive/My Drive

# %%
# !pip install ta
# Out:
# Collecting ta
#   Downloading https://files.pythonhosted.org/packages/3e/d3/749d9c6975a699de8b661113cb835212176baf3b8714389e6f9f51a396da/ta-0.4.5.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from ta) (1.16.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from ta) (0.24.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from ta) (0.21.3)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas->ta) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->ta) (2018.9)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->ta) (1.3.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->ta) (0.14.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.5.0->pandas->ta) (1.12.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.4.5-cp36-none-any.whl size=16698 sha256=787cd25a2aba11c4f201582d23f40b9cc0670f96fd341d0093a8606fd1cd795d
#   Stored in directory: /root/.cache/pip/wheels/de/ac/09/28855b628633d42061f670c59df6877a1dbdf70d04c985bc18
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.4.5

# %%
import numpy as np
from scipy.special import expit
import pandas as pd
import pickle
from numba import jit as njit
from functools import lru_cache
from multiprocessing import Pool
import os
import time
import random
import ta
from net import *
from memory import *
from reward import *

# %%
class neuralnetwork:
    def __init__(self, id_, hidden_size = 128, window_size = 30, restore=False):
        if restore:
          f = open("./neuro_w.txt","rb")
          weights = pickle.load(f)
          self.W1 = weights[0]
          self.W2 = weights[1]
          self.W3 = np.random.randn(hidden_size, 3)
          # self.W3 = weights[2]
        else:
          self.W1 = np.random.randn(window_size, hidden_size)# / np.sqrt(window_size)
          self.W2 = np.random.randn(hidden_size, window_size)# / np.sqrt(hidden_size)
          self.W3 = np.random.randn(window_size, hidden_size*2)# / np.sqrt(hidden_size)
          self.W4 = np.random.randn(hidden_size*2, 3)# / np.sqrt(hidden_size)
        self.fitness_list = []
        self.fitness = 0
        self.id = id_

@njit
def gaussiandropout(w,rate,train=True):
  if train:
    if 0. < rate < 1.:
      scale = np.sqrt(rate / (1. - rate))
      w *= np.random.normal(1.,scale,w.shape)
  return w

# @njit
def sigmoid(x):
  x = 1 / (1 + expit(-x))
  return x

# @njit
def swish(x):
  x *= sigmoid(x)
  return x
 
def relu(X):
    return np.maximum(X, 0)
  
# @njit
def softmax(X):
    e_x = np.exp(X - np.max(X, axis=-1, keepdims=True))
    e_x /= np.sum(e_x, axis=-1, keepdims=True)
    return e_x
  
@njit
def feed_forward(X, nets,rate=0.2,train=True):
    X = X.flatten().reshape(1,-1)
    # w1 = gaussiandropout(nets.W1,rate,train)
    a1 = np.dot(X, nets.W1)
    z1 = swish(a1)
    a2 = np.dot(z1,nets.W2)
    z2 = softmax(a2)
    z2 = np.multiply(X,z2)
    a3 = swish(np.dot(z2, nets.W3))
    a3 = np.dot(a3,nets.W4)
    return np.tanh(a3)

# %%
class NeuroEvolution:
    def __init__(self, population_size, mutation_rate, model_generator, state_size, window_size, path, step_size, spread=10, pip_cost=1000, los_cut=20,restore=False):
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.mutation_rate_origin = mutation_rate
        self.model_generator = model_generator
        self.state_size = state_size
        self.window_size = window_size
        self.path = path
        self.step_size = step_size
        self.spread = spread / pip_cost
        self.pip_cost = pip_cost
        self.los_cut = los_cut
        self.restore = restore
        self.preproc()
        self.rewards = reward3
        self.fittest_individual = None
        
    def preproc(self):
          self.dat = df = pd.read_csv(self.path)
          s = np.asanyarray(ta.stoch(df["High"],df["Low"],df["Close"],14)).reshape((-1, 1)) - np.asanyarray(ta.stoch_signal(df["High"],df["Low"],df["Close"],14)).reshape((-1, 1))
          x = np.asanyarray(ta.daily_log_return(df["Close"])).reshape((-1,1))
          m = np.asanyarray(ta.macd_diff(df["Close"])).reshape((-1,1))
          # x = m
          x = np.concatenate([m,s,x], 1)
          y = np.asanyarray(self.dat[["Open"]])

          gen = tf.keras.preprocessing.sequence.TimeseriesGenerator(x, y, self.window_size)
          self.x = []
          self.y = []
          for i in gen:
              self.x.extend(i[0].tolist())
              self.y.extend(i[1].tolist())
          self.x = np.asanyarray(self.x)
          self.y = np.asanyarray(self.y)

          self.df = self.x[-self.step_size::]
          self.trend = self.y[-self.step_size::]

    def _initialize_population(self):
        self.population = []
        for i in range(self.population_size):
            self.population.append(self.model_generator(i,window_size = self.window_size*self.df.shape[-1], restore=self.restore))
    
    def mutate(self, individual, scale=1.0):
      if np.random.random() < 0.1:
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W1.shape)
        individual.W1 += np.random.normal(loc=0, scale=scale, size=individual.W1.shape) * mutation_mask
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W2.shape)
        individual.W2 += np.random.normal(loc=0, scale=scale, size=individual.W2.shape) * mutation_mask
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W3.shape)
        individual.W3 += np.random.normal(loc=0, scale=scale, size=individual.W3.shape) * mutation_mask
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W4.shape)
        individual.W4 += np.random.normal(loc=0, scale=scale, size=individual.W4.shape) * mutation_mask
      return individual
    
    def inherit_weights(self, parent, child):
        child.W1 = parent.W1.copy()
        child.W2 = parent.W2.copy()
        child.W3 = parent.W3.copy()
        child.W4 = parent.W4.copy()
        return child
    
    def crossover(self, parent1, parent2):
        child1 = self.model_generator((parent1.id+1)*10)
        child1 = self.inherit_weights(parent1, child1)
        child2 = self.model_generator((parent2.id+1)*10)
        child2 = self.inherit_weights(parent2, child2)
        # 
        n_neurons = child1.W1.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W1[:, cutoff:] = parent2.W1[:, cutoff:].copy()
        child2.W1[:, cutoff:] = parent1.W1[:, cutoff:].copy()
        # 
        n_neurons = child1.W2.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W2[:, cutoff:] = parent2.W2[:, cutoff:].copy()
        child2.W2[:, cutoff:] = parent1.W2[:, cutoff:].copy()
        # 
        n_neurons = child1.W3.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W3[:, cutoff:] = parent2.W3[:, cutoff:].copy()
        child2.W3[:, cutoff:] = parent1.W3[:, cutoff:].copy()
        # 
        n_neurons = child1.W4.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W4[:, cutoff:] = parent2.W4[:, cutoff:].copy()
        child2.W4[:, cutoff:] = parent1.W4[:, cutoff:].copy()
        return child1, child2
    
    def act(self, p, state, rate=0.2,train=True):
        logits = feed_forward(state, p, rate, train)
        return np.argmax(logits, 1)[0]
#         return np.argmax(logits[0])
    
    def test(self, individual, i):
        states = []
        pip = []
        history = []
        h_p = []
        provisional_pip = []
        total_pip = 0.0
        position = 3
        h = np.random.randint(100,self.x.shape[0]-(self.step_size+1))
        self.df = self.x[h:h+self.step_size]
        self.trend = self.y[h:h+self.step_size]
        for t in range(0, len(self.trend) - 1):
            action = self.act(individual, self.df[t], train=False)
            history.append(action)
            states,provisional_pip,position,total_pip = self.rewards(self.trend[t],pip,provisional_pip,action,
                                                                     position,states,self.pip_cost,self.spread,total_pip,lc=self.los_cut/1000)
#             print(len(provisional_pip))
            h_p.append(position)
        fitness = total_pip * self.pip_cost
        self.pip = np.asanyarray(provisional_pip) * self.pip_cost
        self.pip = [p if p >= -self.los_cut else -self.los_cut for p in self.pip]
        self.total_pip = np.sum(self.pip)
        mean_pip = self.total_pip / (t + 1)
        trade_accuracy = np.mean(np.asanyarray(self.pip) > 0)
        self.trade = trade_accuracy
        mean_pip *= 96
        prob = self.prob(history)
        position_prob = self.prob(h_p)
      
        print("")
        print('action probability = ', prob)
        print("buy = ", position_prob[1], " sell = ", position_prob[-1])
        print('trade accuracy = ', trade_accuracy)
        print('epoch: %d, total rewards: %f, mean rewards: %f' % (i+1, float(self.total_pip), float(mean_pip)))
    
    def run_fit(self,i):
      accuracy = 0
      for _ in range(20):
        h = np.random.randint(self.x.shape[0]-(24+1))
        df = self.x[h:h+24]
        trend = self.y[h:h+24]
        states = []
        pip = []
        provisional_pip = []
        total_pip = 0.0
        position = 3
        for t in range(0, len(trend) - 1):
            action = self.act(i, df[t])
            states,provisional_pip,position,total_pip = self.rewards(trend[t],pip,provisional_pip,
                                                                      action,position,states,self.pip_cost,self.spread,total_pip,lc=self.los_cut/1000)
        accuracy += np.mean(np.array(provisional_pip) > 0) * 100
        
      return accuracy
    
    def calculate_fitness(self):
        p = Pool(os.cpu_count())
        # args = range(self.population_size)
        fitness_list = p.map(self.run_fit, self.population)
        p.close()
        for i in range(self.population_size):
          self.population[i].fitness = fitness_list[i]

    def prob(self,history):
        prob = np.asanyarray(history)
        a = np.mean(prob == 0)
        b = np.mean(prob == 1)
        c = 1 - (a + b)
        prob = [a,b,c]
        return prob
    
    def sort(self):
        self.fitnesses = fitnesses = [i.fitness for i in self.population]
        fitnesses = np.array(neural_evolve.fitnesses).flatten()
        self.sort_fitness = sort_fitness = np.argsort(neural_evolve.fitnesses,None)[::-1]
        self.population = [self.population[int(i)] for i in sort_fitness]
        self.fittest_individual = fittest_individual = self.population[0]

    def evolve(self, generations=20, checkpoint= 5):
        self._initialize_population()
        n_winners = int(self.population_size * 0.1)
        n_parents = self.population_size - n_winners
        for epoch in range(generations):
            if epoch % 10 == 0:
              self.change = True
            self.calculate_fitness()
            self.sort()
            if (epoch+1) % checkpoint == 0:
                self.test(self.fittest_individual, epoch)
                save = [self.fittest_individual.W1, self.fittest_individual.W2, self.fittest_individual.W3]
                f = open('neuro_w.txt', 'wb')
                # f2 = open('neuro_train.txt', 'wb')
                pickle.dump(save, f)
            next_population = [self.population[i] for i in range(n_winners)]
            total_fitness = np.sum([np.abs(i.fitness) for i in self.population])
            parent_probabilities = [np.abs(i.fitness / total_fitness) for i in self.population]
            sort_probabilities = np.argsort(parent_probabilities,None).reshape(-1,1)
            parent_probabilities = [parent_probabilities[int(i)] for i in sort_probabilities]
            parent_probabilities = np.array(parent_probabilities).flatten()
            parents = np.random.choice(self.population, size=n_parents, p=parent_probabilities, replace=False)
            if (epoch + 1) % 1000:
              new = int(n_parents * 0.1)
            else:
              new = 0
            length = int(len(parents)-new)
            for i in range(0, length, 2):
                child1, child2 = self.crossover(parents[i], parents[i+1])
                next_population += [self.mutate(child1), self.mutate(child2)]
            if new != 0:
              for _ in range(new):
                next_population.append(self.model_generator(0,window_size = self.window_size*self.df.shape[-1], restore=self.restore))
            self.population = next_population

# %%
population_size = 100
generations = 100
mutation_rate = 0.01
window_size = 30
step_size = 24 * 20
los_cut = 300
restore = False
path = "audpred60.csv"

neural_evolve = NeuroEvolution(population_size, mutation_rate, neuralnetwork,
                              window_size, window_size, path, step_size,restore=restore, los_cut=los_cut)

# %%
fittest_nets = neural_evolve.evolve(50000,1)
# Out:
# action probability =  [0.44258872651356995, 0.2359081419624217, 0.32150313152400833]
# buy =  0.6283924843423799  sell =  0.37160751565762007
# trade accuracy =  0.44541484716157204
# epoch: 1, total rewards: -450.000000, mean rewards: -90.187891
#
# action probability =  [0.37160751565762007, 0.35281837160751567, 0.2755741127348643]
# buy =  0.5260960334029228  sell =  0.47390396659707723
# trade accuracy =  0.4496124031007752
# epoch: 2, total rewards: 4227.000000, mean rewards: 847.164927
#
# action probability =  [0.42171189979123175, 0.25052192066805845, 0.32776617954070986]
# buy =  0.6325678496868476  sell =  0.36743215031315235
# trade accuracy =  0.48120300751879697
# epoch: 3, total rewards: 18908.000000, mean rewards: 3789.494781
#
# action probability =  [0.35908141962421714, 0.325678496868476, 0.3152400835073068]
# buy =  0.5156576200417536  sell =  0.48434237995824636
# trade accuracy =  0.4153225806451613
# epoch: 4, total rewards: -8721.000000, mean rewards: -1747.841336
#
# action probability =  [0.3966597077244259, 0.32150313152400833, 0.28183716075156573]
# buy =  0.5427974947807933  sell =  0.4572025052192067
# trade accuracy =  0.44017094017094016
# epoch: 5, total rewards: 3262.000000, mean rewards: 653.762004
#
# action probability =  [0.40292275574112735, 0.33194154488517746, 0.2651356993736952]
# buy =  0.5490605427974948  sell =  0.45093945720250517
# trade accuracy =  0.48854961832061067
# epoch: 6, total rewards: 10303.000000, mean rewards: 2064.901879
#
# action probability =  [0.35490605427974947, 0.267223382045929, 0.3778705636743216]
# buy =  0.5762004175365344  sell =  0.4237995824634656
# trade accuracy =  0.47161572052401746
# epoch: 7, total rewards: 5596.000000, mean rewards: 1121.536534
#
# action probability =  [0.35490605427974947, 0.26931106471816285, 0.3757828810020877]
# buy =  0.5762004175365344  sell =  0.4237995824634656
# trade accuracy =  0.5096153846153846
# epoch: 8, total rewards: 7072.000000, mean rewards: 1417.352818
#
# action probability =  [0.40501043841336115, 0.3444676409185804, 0.25052192066805845]
# buy =  0.5302713987473904  sell =  0.4697286012526096
# trade accuracy =  0.4247104247104247
# epoch: 9, total rewards: -3722.000000, mean rewards: -745.954071
#
# action probability =  [0.33820459290187893, 0.2818371607515658, 0.3799582463465553]
# buy =  0.5135699373695198  sell =  0.48643006263048016
# trade accuracy =  0.4166666666666667
# epoch: 10, total rewards: 1192.000000, mean rewards: 238.897704
#
# action probability =  [0.4279749478079332, 0.2985386221294363, 0.2734864300626305]
# buy =  0.5657620041753654  sell =  0.4342379958246346
# trade accuracy =  0.4186046511627907
# epoch: 11, total rewards: 5861.000000, mean rewards: 1174.647182
#
# action probability =  [0.4154488517745303, 0.35908141962421714, 0.22546972860125258]
# buy =  0.524008350730689  sell =  0.47599164926931103
# trade accuracy =  0.5371024734982333
# epoch: 12, total rewards: 7122.000000, mean rewards: 1427.373695
#
# action probability =  [0.31315240083507306, 0.40083507306889354, 0.28601252609603334]
# buy =  0.4509394572025052  sell =  0.5490605427974948
# trade accuracy =  0.45634920634920634
# epoch: 13, total rewards: 1496.000000, mean rewards: 299.824635
#
# action probability =  [0.40501043841336115, 0.31106471816283926, 0.28392484342379953]
# buy =  0.5448851774530271  sell =  0.4551148225469729
# trade accuracy =  0.416
# epoch: 14, total rewards: -5261.000000, mean rewards: -1054.396660
#
# action probability =  [0.3235908141962422, 0.32150313152400833, 0.3549060542797495]
# buy =  0.5093945720250522  sell =  0.49060542797494777
# trade accuracy =  0.5021645021645021
# epoch: 15, total rewards: 8170.000000, mean rewards: 1637.411273
#
# action probability =  [0.3444676409185804, 0.35490605427974947, 0.3006263048016702]
# buy =  0.4759916492693111  sell =  0.524008350730689
# trade accuracy =  0.5060728744939271
# epoch: 16, total rewards: 1431.000000, mean rewards: 286.797495
#
# action probability =  [0.33820459290187893, 0.3089770354906054, 0.3528183716075157]
# buy =  0.5323590814196242  sell =  0.4676409185803758
# trade accuracy =  0.4801762114537445
# epoch: 17, total rewards: 5279.000000, mean rewards: 1058.004175
#
# action probability =  [0.3674321503131524, 0.29227557411273486, 0.3402922755741127]
# buy =  0.5762004175365344  sell =  0.4237995824634656
# trade accuracy =  0.5062240663900415
# epoch: 18, total rewards: 10658.000000, mean rewards: 2136.050104
#
# action probability =  [0.3444676409185804, 0.3966597077244259, 0.25887265135699367]
# buy =  0.47390396659707723  sell =  0.5260960334029228
# trade accuracy =  0.43873517786561267
# epoch: 19, total rewards: -6382.000000, mean rewards: -1279.064718
#
# action probability =  [0.4112734864300626, 0.2609603340292276, 0.32776617954070986]
# buy =  0.6179540709812108  sell =  0.3820459290187892
# trade accuracy =  0.4722222222222222
# epoch: 20, total rewards: -2849.000000, mean rewards: -570.989562
#
# action probability =  [0.31524008350730687, 0.33820459290187893, 0.3465553235908142]
# buy =  0.4968684759916493  sell =  0.5031315240083507
# trade accuracy =  0.41739130434782606
# epoch: 21, total rewards: -3141.000000, mean rewards: -629.511482
#
# action probability =  [0.36325678496868474, 0.4154488517745303, 0.22129436325678498]
# buy =  0.47390396659707723  sell =  0.5260960334029228
# trade accuracy =  0.4411764705882353
# epoch: 22, total rewards: -37.000000, mean rewards: -7.415449
#
# action probability =  [0.4551148225469729, 0.24425887265135698, 0.3006263048016702]
# buy =  0.6701461377870563  sell =  0.32985386221294366
# trade accuracy =  0.5282258064516129
# epoch: 23, total rewards: 11646.000000, mean rewards: 2334.062630
#
# action probability =  [0.3862212943632568, 0.2359081419624217, 0.3778705636743215]
# buy =  0.6137787056367432  sell =  0.3862212943632568
# trade accuracy =  0.42920353982300885
# epoch: 24, total rewards: 4909.000000, mean rewards: 983.849687
#
# action probability =  [0.5073068893528184, 0.21711899791231734, 0.2755741127348642]
# buy =  0.7035490605427975  sell =  0.29645093945720247
# trade accuracy =  0.4435483870967742
# epoch: 25, total rewards: -3197.000000, mean rewards: -640.734864
#
# action probability =  [0.34237995824634654, 0.40083507306889354, 0.25678496868475986]
# buy =  0.4363256784968685  sell =  0.5636743215031315
# trade accuracy =  0.48638132295719844
# epoch: 26, total rewards: 1615.000000, mean rewards: 323.674322
#
# action probability =  [0.40083507306889354, 0.2609603340292276, 0.3382045929018789]
# buy =  0.615866388308977  sell =  0.384133611691023
# trade accuracy =  0.4533898305084746
# epoch: 27, total rewards: 93.000000, mean rewards: 18.638831
#
# action probability =  [0.3465553235908142, 0.3569937369519833, 0.2964509394572026]
# buy =  0.46764091858037576  sell =  0.5323590814196242
# trade accuracy =  0.5058365758754864
# epoch: 28, total rewards: 7837.000000, mean rewards: 1570.672234
#
# action probability =  [0.47390396659707723, 0.2797494780793319, 0.24634655532359084]
# buy =  0.6283924843423799  sell =  0.37160751565762007
# trade accuracy =  0.4291044776119403
# epoch: 29, total rewards: -3834.000000, mean rewards: -768.400835
#
# action probability =  [0.3173277661795407, 0.36116910229645094, 0.32150313152400833]
# buy =  0.46346555323590816  sell =  0.5365344467640918
# trade accuracy =  0.46124031007751937
# epoch: 30, total rewards: -1058.000000, mean rewards: -212.041754
#
# action probability =  [0.34029227557411273, 0.35490605427974947, 0.3048016701461378]
# buy =  0.4968684759916493  sell =  0.5031315240083507
# trade accuracy =  0.544
# epoch: 31, total rewards: 12680.000000, mean rewards: 2541.294363
#
# action probability =  [0.48851774530271397, 0.31315240083507306, 0.1983298538622129]
# buy =  0.592901878914405  sell =  0.40709812108559496
# trade accuracy =  0.4690909090909091
# epoch: 32, total rewards: -1591.000000, mean rewards: -318.864301
#
# action probability =  [0.4175365344467641, 0.3736951983298539, 0.20876826722338204]
# buy =  0.5281837160751566  sell =  0.4718162839248434
# trade accuracy =  0.48905109489051096
# epoch: 33, total rewards: 8281.000000, mean rewards: 1659.657620
#
# action probability =  [0.4321503131524008, 0.3235908141962422, 0.24425887265135704]
# buy =  0.5741127348643006  sell =  0.4258872651356994
# trade accuracy =  0.3798449612403101
# epoch: 34, total rewards: -5389.000000, mean rewards: -1080.050104
#
# action probability =  [0.36325678496868474, 0.2755741127348643, 0.36116910229645094]
# buy =  0.5908141962421712  sell =  0.40918580375782876
# trade accuracy =  0.4444444444444444
# epoch: 35, total rewards: -1231.000000, mean rewards: -246.713987
#
# action probability =  [0.3966597077244259, 0.2797494780793319, 0.32359081419624225]
# buy =  0.5824634655532359  sell =  0.4175365344467641
# trade accuracy =  0.4793388429752066
# epoch: 36, total rewards: -1617.000000, mean rewards: -324.075157
#
# action probability =  [0.37995824634655534, 0.3736951983298539, 0.24634655532359084]
# buy =  0.4989561586638831  sell =  0.5010438413361169
# trade accuracy =  0.5468164794007491
# epoch: 37, total rewards: 7137.000000, mean rewards: 1430.379958
#
# action probability =  [0.34029227557411273, 0.36325678496868474, 0.2964509394572026]
# buy =  0.5010438413361169  sell =  0.4989561586638831
# trade accuracy =  0.4881889763779528
# epoch: 38, total rewards: -680.000000, mean rewards: -136.283925
#
# action probability =  [0.33820459290187893, 0.3173277661795407, 0.3444676409185803]
# buy =  0.5135699373695198  sell =  0.48643006263048016
# trade accuracy =  0.43776824034334766
# epoch: 39, total rewards: -753.000000, mean rewards: -150.914405
#
# action probability =  [0.37995824634655534, 0.2776617954070981, 0.3423799582463465]
# buy =  0.55741127348643  sell =  0.44258872651356995
# trade accuracy =  0.42990654205607476
# epoch: 40, total rewards: -1818.000000, mean rewards: -364.359081
#
# action probability =  [0.34029227557411273, 0.4154488517745303, 0.24425887265135704]
# buy =  0.4509394572025052  sell =  0.5490605427974948
# trade accuracy =  0.43795620437956206
# epoch: 41, total rewards: 3447.000000, mean rewards: 690.839248
#
# action probability =  [0.4572025052192067, 0.27139874739039666, 0.2713987473903967]
# buy =  0.6096033402922756  sell =  0.3903966597077244
# trade accuracy =  0.39473684210526316
# epoch: 42, total rewards: -2450.000000, mean rewards: -491.022965
#
# action probability =  [0.3987473903966597, 0.3173277661795407, 0.28392484342379953]
# buy =  0.5511482254697286  sell =  0.44885177453027136
# trade accuracy =  0.45353159851301117
# epoch: 43, total rewards: -1024.000000, mean rewards: -205.227557
#
# action probability =  [0.4509394572025052, 0.37160751565762007, 0.17745302713987465]
# buy =  0.5260960334029228  sell =  0.47390396659707723
# trade accuracy =  0.4521452145214521
# epoch: 44, total rewards: 2895.000000, mean rewards: 580.208768
#
# action probability =  [0.40292275574112735, 0.33611691022964507, 0.2609603340292276]
# buy =  0.5323590814196242  sell =  0.4676409185803758
# trade accuracy =  0.4681647940074906
# epoch: 45, total rewards: 7093.000000, mean rewards: 1421.561587
#
# action probability =  [0.3778705636743215, 0.27348643006263046, 0.3486430062630481]
# buy =  0.6116910229645094  sell =  0.3883089770354906
# trade accuracy =  0.5
# epoch: 46, total rewards: 9725.000000, mean rewards: 1949.060543
#
# action probability =  [0.3924843423799583, 0.2776617954070981, 0.32985386221294366]
# buy =  0.5824634655532359  sell =  0.4175365344467641
# trade accuracy =  0.45045045045045046
# epoch: 47, total rewards: -1096.000000, mean rewards: -219.657620
#
# action probability =  [0.4718162839248434, 0.29018789144050106, 0.23799582463465552]
# buy =  0.6075156576200418  sell =  0.3924843423799582
# trade accuracy =  0.41509433962264153
# epoch: 48, total rewards: -7246.000000, mean rewards: -1452.225470
#
# action probability =  [0.4801670146137787, 0.2150313152400835, 0.3048016701461378]
# buy =  0.6784968684759917  sell =  0.32150313152400833
# trade accuracy =  0.4959349593495935
# epoch: 49, total rewards: 2465.000000, mean rewards: 494.029228
#
# action probability =  [0.3465553235908142, 0.3089770354906054, 0.3444676409185804]
# buy =  0.5553235908141962  sell =  0.44467640918580376
# trade accuracy =  0.4603174603174603
# epoch: 50, total rewards: -132.000000, mean rewards: -26.455115
#
# action probability =  [0.40083507306889354, 0.2839248434237996, 0.3152400835073068]
# buy =  0.5782881002087683  sell =  0.4217118997912317
# trade accuracy =  0.42448979591836733
# epoch: 51, total rewards: -1884.000000, mean rewards: -377.586639
#
# action probability =  [0.3924843423799583, 0.21920668058455114, 0.3883089770354906]
# buy =  0.6263048016701461  sell =  0.3736951983298539
# trade accuracy =  0.46017699115044247
# epoch: 52, total rewards: 662.000000, mean rewards: 132.676409
#
# action probability =  [0.38413361169102295, 0.31315240083507306, 0.302713987473904]
# buy =  0.569937369519833  sell =  0.430062630480167
# trade accuracy =  0.46332046332046334
# epoch: 53, total rewards: -1952.000000, mean rewards: -391.215031
#
# action probability =  [0.17745302713987474, 0.46346555323590816, 0.35908141962421714]
# buy =  0.2755741127348643  sell =  0.7244258872651357
# trade accuracy =  0.5089285714285714
# epoch: 54, total rewards: 15025.000000, mean rewards: 3011.273486
#
# action probability =  [0.3173277661795407, 0.3235908141962422, 0.35908141962421714]
# buy =  0.48643006263048016  sell =  0.5135699373695198
# trade accuracy =  0.4291845493562232
# epoch: 55, total rewards: -492.000000, mean rewards: -98.605428
#
# action probability =  [0.4175365344467641, 0.3444676409185804, 0.23799582463465552]
# buy =  0.55741127348643  sell =  0.44258872651356995
# trade accuracy =  0.4548872180451128
# epoch: 56, total rewards: -1453.000000, mean rewards: -291.206681
#
# action probability =  [0.3298538622129436, 0.36325678496868474, 0.3068893528183716]
# buy =  0.48643006263048016  sell =  0.5135699373695198
# trade accuracy =  0.43612334801762115
# epoch: 57, total rewards: -3766.000000, mean rewards: -754.772443
#
# action probability =  [0.407098121085595, 0.31524008350730687, 0.2776617954070981]
# buy =  0.5553235908141962  sell =  0.44467640918580376
# trade accuracy =  0.42857142857142855
# epoch: 58, total rewards: -3590.000000, mean rewards: -719.498956
#
# action probability =  [0.4551148225469729, 0.32150313152400833, 0.22338204592901878]
# buy =  0.5720250521920668  sell =  0.4279749478079332
# trade accuracy =  0.4612676056338028
# epoch: 59, total rewards: -2286.000000, mean rewards: -458.154489
#
# action probability =  [0.35281837160751567, 0.3298538622129436, 0.3173277661795407]
# buy =  0.524008350730689  sell =  0.47599164926931103
# trade accuracy =  0.46825396825396826
# epoch: 60, total rewards: 4129.000000, mean rewards: 827.524008
#
# action probability =  [0.3674321503131524, 0.325678496868476, 0.3068893528183716]
# buy =  0.5093945720250522  sell =  0.49060542797494777
# trade accuracy =  0.42127659574468085
# epoch: 61, total rewards: -1954.000000, mean rewards: -391.615866
#
# action probability =  [0.35073068893528186, 0.31106471816283926, 0.3382045929018789]
# buy =  0.5636743215031316  sell =  0.43632567849686843
# trade accuracy =  0.4592274678111588
# epoch: 62, total rewards: -943.000000, mean rewards: -188.993737
#
# action probability =  [0.3048016701461378, 0.34237995824634654, 0.3528183716075157]
# buy =  0.4989561586638831  sell =  0.5010438413361169
# trade accuracy =  0.4730290456431535
# epoch: 63, total rewards: 7363.000000, mean rewards: 1475.674322
#
# action probability =  [0.4405010438413361, 0.2860125260960334, 0.2734864300626305]
# buy =  0.615866388308977  sell =  0.384133611691023
# trade accuracy =  0.4716981132075472
# epoch: 64, total rewards: 7221.000000, mean rewards: 1447.215031
#
# action probability =  [0.38413361169102295, 0.2881002087682672, 0.32776617954070986]
# buy =  0.5824634655532359  sell =  0.4175365344467641
# trade accuracy =  0.45622119815668205
# epoch: 65, total rewards: -793.000000, mean rewards: -158.931106
#
# action probability =  [0.4133611691022965, 0.2776617954070981, 0.3089770354906054]
# buy =  0.6221294363256785  sell =  0.3778705636743215
# trade accuracy =  0.3803921568627451
# epoch: 66, total rewards: -6501.000000, mean rewards: -1302.914405
#
# action probability =  [0.42171189979123175, 0.3298538622129436, 0.24843423799582465]
# buy =  0.5741127348643006  sell =  0.4258872651356994
# trade accuracy =  0.4297872340425532
# epoch: 67, total rewards: -1207.000000, mean rewards: -241.903967
#
# action probability =  [0.40292275574112735, 0.37160751565762007, 0.22546972860125258]
# buy =  0.5052192066805845  sell =  0.4947807933194155
# trade accuracy =  0.49049429657794674
# epoch: 68, total rewards: -2745.000000, mean rewards: -550.146138
#
# action probability =  [0.3173277661795407, 0.2860125260960334, 0.3966597077244258]
# buy =  0.5177453027139874  sell =  0.48225469728601256
# trade accuracy =  0.47058823529411764
# epoch: 69, total rewards: 8243.000000, mean rewards: 1652.041754
#
# action probability =  [0.4363256784968685, 0.2964509394572025, 0.267223382045929]
# buy =  0.5970772442588727  sell =  0.40292275574112735
# trade accuracy =  0.4838709677419355
# epoch: 70, total rewards: 11047.000000, mean rewards: 2214.012526
#
# action probability =  [0.49269311064718163, 0.2860125260960334, 0.22129436325678498]
# buy =  0.6283924843423799  sell =  0.37160751565762007
# trade accuracy =  0.4244604316546763
# epoch: 71, total rewards: -3465.000000, mean rewards: -694.446764
#
# action probability =  [0.40501043841336115, 0.36325678496868474, 0.2317327766179541]
# buy =  0.5198329853862212  sell =  0.48016701461377875
# trade accuracy =  0.5075187969924813
# epoch: 72, total rewards: 6476.000000, mean rewards: 1297.903967
#
# action probability =  [0.3444676409185804, 0.40292275574112735, 0.25260960334029225]
# buy =  0.4780793319415449  sell =  0.5219206680584552
# trade accuracy =  0.4859437751004016
# epoch: 73, total rewards: 9854.000000, mean rewards: 1974.914405
#
# action probability =  [0.3653444676409186, 0.2609603340292276, 0.37369519832985376]
# buy =  0.5991649269311065  sell =  0.40083507306889354
# trade accuracy =  0.4808510638297872
# epoch: 74, total rewards: 1485.000000, mean rewards: 297.620042
#
# action probability =  [0.36325678496868474, 0.3465553235908142, 0.29018789144050106]
# buy =  0.5198329853862212  sell =  0.48016701461377875
# trade accuracy =  0.4605263157894737
# epoch: 75, total rewards: -1513.000000, mean rewards: -303.231733
